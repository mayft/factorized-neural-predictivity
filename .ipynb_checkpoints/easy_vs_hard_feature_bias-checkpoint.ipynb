# %%
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
from sklearn import linear_model
from collections import OrderedDict

from torch.utils.data import Dataset
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

from sklearn.metrics.pairwise import pairwise_distances
from scipy import stats

# %%
NUM_SEEDS = 2
FEATURES = ('linear','xor_xor_xor')

TRAIN_DATASET_SIZE = 4096#32768
TEST_DATASET_SIZE = 1024

BATCH_SIZE = 4096#512

OP_FNS = {'and': np.logical_and, 'or': np.logical_or, 'xor': np.logical_xor}

# %% [markdown]
# # Data

# %%
def make_dataset(features=FEATURES, input_unit_size=16, num_samples=126, seed=123,out=None):
    np.random.seed(seed)
    inputs = np.random.binomial(1, 0.5, size=(num_samples, len(features)*input_unit_size))
    outputs = []

    for feature_i, feature_type in enumerate(features):
        input_unit = inputs[:, feature_i*input_unit_size:(feature_i+1)*input_unit_size]

        if feature_type == 'linear':
            input_unit[:, :4] =  input_unit[:, :1]
            output_unit = input_unit[:, :1]
        else:
            output_unit = np.zeros_like(input_unit[:, :1])
            def feature_val(input):
                top, left, right = [OP_FNS[op] for op in feature_type.split('_')]
                return top(left(input[0], input[1]), right(input[2], input[3]))

            for number, index in enumerate(np.random.permutation(num_samples)):
                while feature_val(input_unit[index]) != number % 2:
                    input_unit[index] = np.random.binomial(1,0.5, input_unit_size)
                output_unit[index] = feature_val(input_unit[index])

        outputs.append(output_unit)
    outs = np.concatenate(outputs,axis=1)
    if out!=None:
        outs= outs[:,out,np.newaxis]
    return {'inputs': inputs, 'labels': outs}

# %%
class Data(Dataset):
    def __init__(self, inputs, labels):
        self.data = inputs.astype(np.float32)
        self.target = labels.astype(np.float32)

    def __getitem__(self, index):
        x = self.data[index]
        y = self.target[index]

        return (x,y)

    def __len__(self):
        return len(self.data)

# %% [markdown]
# # Model

# %%
# initialize weights like flax??
class MLP(nn.Module):
    def __init__(self, layer_sizes: list[int]):
        super(MLP, self).__init__()
        self.layer_sizes = layer_sizes
        layers = []
        for i in range(len(layer_sizes)-2):
            layers.append((f'linear_{i}',nn.Linear(layer_sizes[i],layer_sizes[i+1])))
            layers.append((f'leaky_relu_{i}',nn.LeakyReLU()))
        self.model_body = nn.Sequential(OrderedDict(layers))
        self.output = nn.Linear(layer_sizes[-2], layer_sizes[-1])

    def forward(self, x):
        x = self.model_body(x)
        out = self.output(x)
        return out, x

# %% [markdown]
# # Analysis

# %%
def analyze_rep_var_explained(fit_reps, fit_labels, test_reps, test_labels):
    scores = []
    total_var = np.sum(np.var(test_reps,axis=0))

    for feat in range(fit_labels.shape[-1]):
        regr = linear_model.LinearRegression()
        regr.fit(fit_labels[:, feat:feat+1], fit_reps)
        scores.append(regr.score(test_labels[:, feat:feat+1], test_reps))

    return scores, total_var

# %%
def pred(loader,model):
    model.eval()
    ys =[]
    rs = []
    with (torch.no_grad()):
        for X ,y in loader:
            X=X.to(torch.device('mps'))
            y=y.to(torch.device('mps'))
            y_pred, rps = model(X)

            outs = ((y_pred>0) == y).float()
            outs = outs.mean().item()
            ys.append(outs)
            rs.append(rps)
    model.train()
    o=(*ys,)

    return np.mean(ys), rs[0]

# %%
def accuracy(y,labels,features=None):
    accs = []
    if features == 'all' or not features:
        out = ((y>0) == labels).float().mean()
        accs.append(out)
    if features == 'separate' or features =='all':
        for i in range(len(y[0])):
            out = ((y[:,i]>0) == labels[:,i]).float().mean().cpu().numpy()
            accs.append(out)

    return accs

# %% [markdown]
# # Training

# %%
def train_epoch(model, train_loader, criterion,optimizer):
    '''
    for each epoch
        iterate over batches updating model
    '''
    total_loss = 0 # should it be mean or sum??
    for inputs, labels in train_loader:
        outputs, _ = model(inputs)

        #l1 = criterion(outputs[:,0],labels[:,0]).item()
        #l2 = 0#criterion(outputs[:,1],labels[:,1]).item()
        loss = criterion(outputs, labels)

        optimizer.zero_grad()
        loss.backward()

        optimizer.step()
        total_loss += loss.item()

    return total_loss

# %%
def train_epoch_(model, x, y, criterion, optimizer):
    outputs, _ = model(x)
    loss = criterion(outputs, y)

    optimizer.zero_grad()
    loss.backward()
    optimizer.step()


    return loss.item()

# %%
# write results to csv file


def run(features=FEATURES, units_per_feature=16, verbose=0,n=2, seeds=NUM_SEEDS):
    rvs = []
    models=[]
    global acc
    acc = []
    global reps
    reps = []
    for seed in range(seeds):
        torch.manual_seed(123+seed)

        layer_sizes = [units_per_feature*2, 256, 128, 64, 64, len(features)]


        if len(features) == 1:
            feat=FEATURES
            if features[0]=='linear':
                keep = 0
            else:
                keep=1
        else:
            feat = features
            keep =None

        train_data = make_dataset(features=feat, num_samples=TRAIN_DATASET_SIZE, input_unit_size=units_per_feature, seed=123+seed,out=keep)
        val_data = make_dataset(features=feat, num_samples=TEST_DATASET_SIZE, input_unit_size=units_per_feature, seed=1234+seed,out=keep)
        test_data = make_dataset(features=feat, num_samples=TEST_DATASET_SIZE, input_unit_size=units_per_feature, seed=12345+seed,out=keep)


        train_loader = torch.utils.data.DataLoader(Data(train_data['inputs'],train_data['labels']), batch_size=BATCH_SIZE, shuffle=True, )
        val_loader = torch.utils.data.DataLoader(Data(val_data['inputs'],val_data['labels']), batch_size=BATCH_SIZE, shuffle=False)
        test_loader = torch.utils.data.DataLoader(Data(test_data['inputs'],test_data['labels']), batch_size=BATCH_SIZE, shuffle=False)


        model = MLP(layer_sizes=layer_sizes)

        criterion = nn.BCEWithLogitsLoss(reduction='mean')
        #optimizer = optim.Adam(model.parameters(),lr=1e-5)
        optimizer = optim.SGD(model.parameters(),lr=1e-3)
        #scheduler = optim.lr_scheduler.StepLR(optimizer,step_size=5000,gamma=0.5)

        device = torch.device('mps' if torch.mps.is_available() else 'cpu')
        model.to(device)

        x_train = torch.tensor(train_data['inputs'],device=device,dtype=torch.float)
        y_train = torch.tensor(train_data['labels'],device=device,dtype=torch.float)
        x_val = torch.tensor(val_data['inputs'],device=device,dtype=torch.float)
        y_val = torch.tensor(val_data['labels'],device=device,dtype=torch.float)
        x_test = torch.tensor(test_data['inputs'],device=device,dtype=torch.float)
        y_test = torch.tensor(test_data['labels'],device=device,dtype=torch.float)

        for epoch in range(50000):
            model.train(True)
            train_loss = train_epoch_(model,x_train,y_train,criterion, optimizer)#train_epoch(model, train_loader, criterion, optimizer)
            #scheduler.step()
            if epoch%500 ==0:
                model.eval()
                y_pred, test_reps = model(x_test)
                _, val_reps = model(x_val)
                test_loss= criterion(y_pred, y_test)
                acc.append(accuracy(y_pred,y_test,features='separate'))
                variance_scores, total_variance = analyze_rep_var_explained(val_reps.cpu().detach().numpy(), val_data['labels'], test_reps.cpu().detach().numpy(), test_data['labels'])
                reps.append(variance_scores)

                '''for inputs, labels in test_loader:
                    with torch.no_grad():
                        test_loss += criterion(model(inputs)[0], labels)
                '''
                if test_loss < 5e-3:
                    print(f'stopping early at epoch {epoch}')
                    break
            if verbose == 2 or (verbose == 1 and epoch %1000 == 0):
                #train_acc, _ = pred(train_loader,model)
                #val_acc, val_reps = pred(val_loader,model)
                #test_acc, test_reps = pred(test_loader,model)

                '''test_loss = 0
                for X,y in test_loader:
                   # X=X.to(torch.device('mps'))
                    #y=y.to(torch.device('mps'))
                    with torch.no_grad():
                        test_loss += criterion(model(X)[0], y)
                '''
                print(f'Epoch {epoch}: train loss: {train_loss}, test loss: {test_loss}')#, train acc: {train_acc}, val acc: {val_acc}, test acc: {test_acc}')


        val_acc, val_reps = pred(val_loader,model)
        test_acc, test_reps = pred(test_loader,model)
        print(f'seed {seed} acc: {test_acc}, loss: {test_loss}')
        variance_scores, total_variance = analyze_rep_var_explained(val_reps.cpu().numpy(), val_data['labels'], test_reps.cpu().numpy(), test_data['labels'])
        #pc_scores, total_pc = analyze_rep_var_explained(*to_pcs(val_reps.cpu().numpy(), val_data['labels'], test_reps.cpu().numpy(), test_data['labels'],n=n))
        #print(f"Seed {seed} representation variance after training \n"+"\n".join([f'{feature}: {score}' for feature, score in zip(features,variance_scores)]))
        #print(f"Seed {seed} representation variance after training with pc \n"+"\n".join([f'{feature}: {score}' for feature, score in zip(features,pc_scores)]))
        rvs.append([variance_scores])#,pc_scores])
        models.append(model)
    return rvs, models

# %% [markdown]
# # Networks

# %%
repvars, multi_models = run(['linear','xor_xor_xor'],units_per_feature=16,verbose=1,seeds=1)
# Out:
# Epoch 0: train loss: 0.6952091455459595, test loss: 0.6942151188850403
# Epoch 1000: train loss: 0.6943924427032471, test loss: 0.6935142874717712
# Epoch 2000: train loss: 0.6937959790229797, test loss: 0.6930083632469177
# Epoch 3000: train loss: 0.6933350563049316, test loss: 0.6926208138465881
# Epoch 4000: train loss: 0.6929484605789185, test loss: 0.6922940611839294
# Epoch 5000: train loss: 0.692581295967102, test loss: 0.6919804811477661
# Epoch 6000: train loss: 0.6921522617340088, test loss: 0.6916036605834961
# Epoch 7000: train loss: 0.6916674971580505, test loss: 0.691178560256958
# Epoch 8000: train loss: 0.6911779642105103, test loss: 0.6907370090484619
# Epoch 9000: train loss: 0.690639853477478, test loss: 0.6902376413345337
# Epoch 10000: train loss: 0.6900126934051514, test loss: 0.6896429061889648
# Epoch 11000: train loss: 0.6892483830451965, test loss: 0.6889114379882812
# Epoch 12000: train loss: 0.6882889270782471, test loss: 0.6879851818084717
# Epoch 13000: train loss: 0.6870511770248413, test loss: 0.6867814064025879
# Epoch 14000: train loss: 0.6854146718978882, test loss: 0.6851862668991089
# Epoch 15000: train loss: 0.6832013726234436, test loss: 0.6830220818519592
# Epoch 16000: train loss: 0.6801153421401978, test loss: 0.6800018548965454
# Epoch 17000: train loss: 0.6756947636604309, test loss: 0.6756595969200134
# Epoch 18000: train loss: 0.6691900491714478, test loss: 0.669265866279602
# Epoch 19000: train loss: 0.6593152284622192, test loss: 0.6595540046691895
# Epoch 20000: train loss: 0.6437091827392578, test loss: 0.6441692113876343
# Epoch 21000: train loss: 0.6187565326690674, test loss: 0.6195012331008911
# Epoch 22000: train loss: 0.5804128646850586, test loss: 0.5815686583518982
# Epoch 23000: train loss: 0.5273163318634033, test loss: 0.5289983749389648
# Epoch 24000: train loss: 0.4690897464752197, test loss: 0.4711172580718994
# Epoch 25000: train loss: 0.4222080707550049, test loss: 0.4241524934768677
# Epoch 26000: train loss: 0.3928639590740204, test loss: 0.39457136392593384
# Epoch 27000: train loss: 0.3761653006076813, test loss: 0.37759190797805786
# Epoch 28000: train loss: 0.3666147291660309, test loss: 0.3677828907966614
# Epoch 29000: train loss: 0.36091551184654236, test loss: 0.36188945174217224
# Epoch 30000: train loss: 0.3573276996612549, test loss: 0.3581676185131073
# Epoch 31000: train loss: 0.3549434542655945, test loss: 0.35569843649864197
# Epoch 32000: train loss: 0.35328492522239685, test loss: 0.35398659110069275
# Epoch 33000: train loss: 0.3520846366882324, test loss: 0.352753221988678
# Epoch 34000: train loss: 0.3511873185634613, test loss: 0.35183513164520264
# Epoch 35000: train loss: 0.3504974842071533, test loss: 0.35112839937210083
# Epoch 36000: train loss: 0.34995490312576294, test loss: 0.35057419538497925
# Epoch 37000: train loss: 0.34951961040496826, test loss: 0.3501296043395996
# Epoch 38000: train loss: 0.34916263818740845, test loss: 0.349764883518219
# Epoch 39000: train loss: 0.34886622428894043, test loss: 0.34946224093437195
# Epoch 40000: train loss: 0.34861624240875244, test loss: 0.34920722246170044
# Epoch 41000: train loss: 0.34840327501296997, test loss: 0.348987877368927
# Epoch 42000: train loss: 0.348221093416214, test loss: 0.34879907965660095
# Epoch 43000: train loss: 0.3480621576309204, test loss: 0.34863394498825073
# Epoch 44000: train loss: 0.34792423248291016, test loss: 0.34848886728286743
# Epoch 45000: train loss: 0.3478025794029236, test loss: 0.34836071729660034
# Epoch 46000: train loss: 0.3476945161819458, test loss: 0.348248153924942
# Epoch 47000: train loss: 0.34759819507598877, test loss: 0.3481469452381134
# Epoch 48000: train loss: 0.3475114703178406, test loss: 0.3480556607246399
# Epoch 49000: train loss: 0.34743282198905945, test loss: 0.34797289967536926
# seed 0 acc: 0.748046875, loss: 0.3479340374469757

# %%
df = pd.DataFrame(np.transpose([acc,reps]),columns=['easy','hard'])
df['epoch'] = df.index*500
df
#fig, axs = plt.subplots(ncols=2, figsize=(8,4))
#sns.lineplot(data=df,x=epoch,y=,ax=axs[0])

# %%
y1 = torch.tensor(data['labels'],device=torch.device('mps'),dtype=torch.float)
y2 = torch.tensor(data2['labels'],device=torch.device('mps'),dtype=torch.float)

# %%
a = accuracy(y1,y2,features='separate')

# %%
networks ={
    'easy': ['linear'],
    'multitask': ['linear','xor_xor_xor'],
    'hard': ['xor_xor_xor'],
    'multiple easy': ['linear','linear'],
    'multiple hard': ['xor_xor_xor','xor_xor_xor']
}

scores = {}
models = {}

for network, network_features in networks.items():
    print(network)
    scores[network], models[network] = run(network_features, units_per_feature=16, verbose=0, n =2)
# Out:
# easy
# stopping early at epoch 400
# seed 0 acc: 1.0, loss: 0.00013953597226645797
# stopping early at epoch 400
# seed 1 acc: 1.0, loss: 1.862645149230957e-08
# multitask
# stopping early at epoch 16000
# seed 0 acc: 1.0, loss: 0.004917705897241831
# stopping early at epoch 16800
# seed 1 acc: 1.0, loss: 0.004941551014780998
# hard
# stopping early at epoch 18800
# seed 0 acc: 1.0, loss: 0.0023391435388475657
# stopping early at epoch 11000
# seed 1 acc: 1.0, loss: 0.004636154044419527
# multiple easy
# stopping early at epoch 600
# seed 0 acc: 1.0, loss: 0.002603736473247409
# stopping early at epoch 600
# seed 1 acc: 1.0, loss: 8.033410995267332e-05
# multiple hard
# seed 0 acc: 0.9296875, loss: 0.1854841709136963
# seed 1 acc: 0.5, loss: 0.6931471824645996

# %%
for k,v in scores.items():
    print(f'{k}: {np.mean(v,axis=0)}')
# Out:
# easy: [[0.87733549]
#  [0.49505375]]
# multitask: [[0.71267921 0.04135317]
#  [0.46731547 0.20924178]]
# hard: [[0.72913353]
#  [0.49146211]]
# multiple easy: [[0.46077156 0.41408446]
#  [0.47927817 0.50500554]]
# multiple hard: [[0.00808647 0.24797381]
#  [0.06852101 0.22944919]]

# %% [markdown]
# # RSA

# %%
def rsa(data, model1, model2):
    model1.eval()
    y1, reps1 = model1(data)
    model2.eval()
    y2, reps2 = model2(data)
    reps1 = reps1.cpu().detach().numpy()
    reps2 = reps2.cpu().detach().numpy()

    rdm1 = pairwise_distances(reps1,metric='euclidean')
    rdm2 = pairwise_distances(reps2,metric='euclidean')

    similarity = stats.pearsonr(np.triu(rdm1),np.triu(rdm2),axis=None)

    return similarity.correlation

# %%
data = make_dataset(features=['and_and_and','and_and_and'], num_samples=TRAIN_DATASET_SIZE, input_unit_size=16, seed=12345)
loader = torch.utils.data.DataLoader(Data(data['inputs'],data['labels']),batch_size=BATCH_SIZE,shuffle=False)
stimuli, _ = next(iter(loader))
stimuli = torch.tensor(data['inputs'],device=torch.device('mps'),dtype=torch.float)

# %%
similarities = {}

for i, a in models.items():
    similarities[i] = {}
    for j, b in models.items():
        similarities[i][j] = rsa(stimuli, a[0], b[1])

# %%
df = pd.DataFrame(similarities)
plt1 = df.loc[['hard','multitask','easy'],['easy','multitask','hard']]
plt2 = df.loc[['multiple hard','multiple easy'],['multiple easy','multiple hard']]

c = sns.color_palette("blend:#FFD,#005",as_cmap=True)#.reversed()
fig, axs = plt.subplots(ncols=2, figsize=(10,4))
sns.heatmap(plt1,cmap=c,vmax=1,vmin=0,ax=axs[0])
sns.heatmap(plt2,vmax=1,cmap=c,vmin=0,ax=axs[1])
# Out:
# <Axes: >

# %% [markdown]
# # PCA

# %%
def to_pcs(fit_activations, fit_labels, test_activations, test_labels,n=2):
    X = fit_activations#.cpu().detach().numpy()
    X_std = (X-np.mean(X))/np.std(X)
    pca = PCA(n_components=n,svd_solver='full')
    pca.fit(X_std)
    X = test_activations#.cpu().detach().numpy()
    X_test = (X-np.mean(X))/np.std(X)
    fit_pcs = pca.transform(X_std)
    test_pcs = pca.transform(X_test)
    y_fit = (fit_labels[:,:]>0).astype(int)
    y_test = (test_labels[:,:]>0).astype(int)
    #return #np.append(test_pcs,y,axis=-1)
    return fit_pcs,y_fit,test_pcs,y_test

# %%
#_,_, mxor = run(['xor_xor_xor'], units_per_feature=32, verbose=0)
#_,_, mlin = run(['linear'], units_per_feature=32, verbose=0)
#_, m = run(['xor_xor_xor','xor_xor_xor'], units_per_feature=16, verbose=0)
m = models['multitask'][0]
m.to(torch.device('cpu'))
# Out:
# MLP(
#   (model_body): Sequential(
#     (linear_0): Linear(in_features=32, out_features=256, bias=True)
#     (leaky_relu_0): LeakyReLU(negative_slope=0.01)
#     (linear_1): Linear(in_features=256, out_features=128, bias=True)
#     (leaky_relu_1): LeakyReLU(negative_slope=0.01)
#     (linear_2): Linear(in_features=128, out_features=64, bias=True)
#     (leaky_relu_2): LeakyReLU(negative_slope=0.01)
#     (linear_3): Linear(in_features=64, out_features=64, bias=True)
#     (leaky_relu_3): LeakyReLU(negative_slope=0.01)
#   )
#   (output): Linear(in_features=64, out_features=2, bias=True)
# )

# %%
data = make_dataset(features=['linear','xor_xor_xor'], num_samples=TEST_DATASET_SIZE, input_unit_size=16, seed=12345)
loader = torch.utils.data.DataLoader(Data(data['inputs'],data['labels']),batch_size=BATCH_SIZE,shuffle=False)
at = None
p = None
for batch_data in loader:
    inputs,labels = batch_data
    #inputs = inputs.to(torch.device('mps'))

    m.eval()
    p, at = m(inputs)

# %%
data2 = make_dataset(features=['linear', 'xor_xor_xor'], num_samples=TEST_DATASET_SIZE, input_unit_size=16, seed=1234)
loader2 = torch.utils.data.DataLoader(Data(data2['inputs'], data2['labels']), batch_size=BATCH_SIZE, shuffle=False)
at2 = None
p2 = None
for batch_data in loader2:
    inputs, labels = batch_data
    #inputs = inputs.to(torch.device('mps'))

    m.eval()
    p2, at2 = m(inputs)

# %%
pcs = to_pcs(at.detach().numpy(),p.detach().numpy(),at2.detach().numpy(),p2.detach().numpy(),n=8)

# %%
scs, tot = analyze_rep_var_explained(pcs[0],pcs[1],pcs[2],pcs[3])
print(scs)
print(tot)
# Out:
# [-0.2021485381252346, -0.19742266406718806]
# 26.101467

# %%
scs, tot = analyze_rep_var_explained(at.detach().numpy(),p.detach().numpy(),at2.detach().numpy(),p2.detach().numpy())
print(scs)
print(tot)
# Out:
# [0.7766475081443787, 0.05411262437701225]
# 64.50815

# %%
a= at.detach().numpy()

act = (a-np.mean(a))/np.std(a)
pca = PCA(n_components=8,svd_solver='full')
pcs = pca.fit_transform(act)

# %%
colorfilter = (p.detach().numpy()[:,0] >0)
shapefilter = (p.detach().numpy()[:,1] >0)

# %%
#d = pd.DataFrame(to_pcs(at,p,at,p))
pc= pd.DataFrame(pcs)
pc['easy'] = colorfilter.astype(int)
pc['hard'] = shapefilter.astype(int)
d=pc

# %%
fig, axs = plt.subplots(ncols=3,nrows=1, figsize=(16,4))
sns.scatterplot(data=d,x=1,y=0,hue='easy',style='hard',ax=axs[0])
sns.scatterplot(data=d,x=3,y=2,hue='easy',style='hard',ax=axs[1])
sns.scatterplot(data=d,x=5,y=4,hue='easy',style='hard',ax=axs[2])
#sns.scatterplot(data=d,x=7,y=6,hue='easy',style='hard',ax=axs[1][0])
plt.show()

# %% [markdown]
# # Neural Predictivity

# %%
def score(activation1, activation2,activations1_test,activation2_test):
    regr = linear_model.LinearRegression()
    regr.fit(activation1, activation2)
    pred = regr.predict(activations1_test)
    corr_score = stats.pearsonr(pred,activation2_test,axis=None)
    reg_score = regr.score(activations1_test, activation2_test)
    return corr_score, reg_score

# %%
data = make_dataset(features=['linear','xor_xor_xor'], num_samples=TEST_DATASET_SIZE, input_unit_size=16, seed=12345)
x1 = torch.tensor(data['inputs'],device=torch.device('mps'),dtype=torch.float)
data2 = make_dataset(features=['linear','xor_xor_xor'], num_samples=TEST_DATASET_SIZE, input_unit_size=16, seed=1234)
x2 = torch.tensor(data2['inputs'],device=torch.device('mps'),dtype=torch.float)

# %%
fitx = models['multitask'][0](x1)[1].cpu().detach()
testx =models['multitask'][0](x2)[1].cpu().detach()

fity = models['easy'][1](x1)[1].cpu().detach()
testy =models['easy'][1](x2)[1].cpu().detach()

# %%
preds = {}

for i, a in models.items():
    preds[i] = {}
    for j, b in models.items():
        fitx = a[0](x1)[1].cpu().detach()
        testx =a[0](x2)[1].cpu().detach()

        fity = b[1](x1)[1].cpu().detach()
        testy = b[1](x2)[1].cpu().detach()
        _,preds[i][j] = score(fitx,fity,testx,testy)

# %%
df = pd.DataFrame(preds)


c = sns.color_palette("blend:#FFD,#005",as_cmap=True)#.reversed()
#fig, axs = plt.subplots(ncols=2, figsize=(10,4))

ax = sns.heatmap(df,cmap=c)
ax.invert_yaxis()
plt.show()

# %%
predspc = {}

for i, a in models.items():
    predspc[i] = {}
    for j, b in models.items():
        p, at = a[0](x1)
        p2,at2 =a[0](x2)
        fitx,_,testx,_ = to_pcs(at.cpu().detach().numpy(),p.cpu().detach().numpy(),at2.cpu().detach().numpy(),p2.cpu().detach().numpy(),n=6)


        fity = b[1](x1)[1].cpu().detach()
        testy = b[1](x2)[1].cpu().detach()
        _,predspc[i][j] = score(fitx,fity,testx,testy)

# %%
df2 = pd.DataFrame(predspc)


c = sns.color_palette("blend:#FFD,#005",as_cmap=True)#.reversed()
#fig, axs = plt.subplots(ncols=2, figsize=(10,4))

ax = sns.heatmap(df2,cmap=c)
ax.invert_yaxis()
plt.show()
